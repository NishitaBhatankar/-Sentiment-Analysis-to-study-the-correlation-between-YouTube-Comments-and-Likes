# %%
import requests
import pandas as pd
import time
from googleapiclient.discovery import build
import seaborn as sns
import random

# %%
API_KEY="(INPUT API KEY)"
channel_id=['UCW8Ews7tdKKkBT6GdtQaXvQ','UCLLw7jmFsvfIVaUFsLs8mlQ','UC0k238zFx-Z8xFH0sxCrPJg','UC-lHJZR3Gqxm24_Vd_AJ5Yw','UCh3Rpsdv1fxefE0ZcKBaNcQ','UCvlVuntLjdURVD3b3Hx7kxw','UCPF-oYb2-xN5FbCXy0167Gg','UC16niRr50-MSBwiO3YDb3RA']

youtube= build('youtube','v3',developerKey=API_KEY)

# %%
def get_channel(youtube,channel_id):
  data=[]
  request=youtube.channels().list(
      part='snippet,contentDetails,statistics',
      id=','.join(channel_id))
  response=request.execute()

  for i in range(len(response['items'])):

    data.append(dict(channel_name = response['items'][i]['snippet']['title'],
              subscriber=response['items'][i]['statistics']['subscriberCount'],
              view=response['items'][i]['statistics']['viewCount'],
              totalVideo=response['items'][i]['statistics']['videoCount'],
              playlist_id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
              ))
  return data

# %%
channel_data=get_channel(youtube,channel_id)

# %%
channel_data=pd.DataFrame(channel_data)

# %%
channel_data
# Out:
#            channel_name subscriber  ... totalVideo               playlist_id
# 0              touropia     876000  ...        101  UUh3Rpsdv1fxefE0ZcKBaNcQ
# 1         Luke Barousse     133000  ...         70  UULLw7jmFsvfIVaUFsLs8mlQ
# 2         StrataScratch      23800  ...         82  UUW8Ews7tdKKkBT6GdtQaXvQ
# 3              BBC News   11300000  ...      15318  UU16niRr50-MSBwiO3YDb3RA
# 4        Dry Bar Comedy    1880000  ...       1887  UUvlVuntLjdURVD3b3Hx7kxw
# 5      Roel Van de Paar      61900  ...    1886588  UUPF-oYb2-xN5FbCXy0167Gg
# 6  Architectural Digest    5010000  ...        489  UU0k238zFx-Z8xFH0sxCrPJg
# 7             PewDiePie  111000000  ...       4456  UU-lHJZR3Gqxm24_Vd_AJ5Yw
#
# [8 rows x 5 columns]

# %%
playlist_id=[]

# %%
for i in range(len(channel_data)):
  playlist_id.append(channel_data['playlist_id'][i])

# %%
playlist_id
# Out:
# ['UUh3Rpsdv1fxefE0ZcKBaNcQ',
#  'UULLw7jmFsvfIVaUFsLs8mlQ',
#  'UUW8Ews7tdKKkBT6GdtQaXvQ',
#  'UU16niRr50-MSBwiO3YDb3RA',
#  'UUvlVuntLjdURVD3b3Hx7kxw',
#  'UUPF-oYb2-xN5FbCXy0167Gg',
#  'UU0k238zFx-Z8xFH0sxCrPJg',
#  'UU-lHJZR3Gqxm24_Vd_AJ5Yw']

# %%
def get_video(youtube,playlist_id):
  video_ids=[]
  request=youtube.playlistItems().list(
      part='contentDetails',
      playlistId=playlist_id,
      maxResults=50
  )
 
  response=request.execute()
  print(response)
  for j in range(len(response['items'])):
    video_ids.append(response['items'][j]['contentDetails']['videoId'])
  

  next_page_token=response['nextPageToken']
  more_pages=True

  while more_pages:
    if next_page_token is None:
      more_pages=False
    else:
      request=youtube.playlistItems().list(
          part='contentDetails',
          playlistId=playlist_id,
          pageToken=next_page_token,
          maxResults=100)
      response=request.execute()

      for k in range(len(response['items'])):
        video_ids.append(response['items'][k]['contentDetails']['videoId'])

      next_page_token=response.get('nextPageToken')

  print(len(video_ids))
  return video_ids

# %%
video_id=[]

# %%
for i in range(len(playlist_id)):
  print(playlist_id[i])
  video_id.append(get_video(youtube,playlist_id[i]))
# Out:
# UUh3Rpsdv1fxefE0ZcKBaNcQ
# ...

# %%
video_id

# %%
list_id=[]

# %%
for i in range(len(video_id)):
  print(video_id[i])
  for j in range(len(video_id[i])):
    print(video_id[i][j])
    list_id.append(video_id[i][j])

# %%
list_id

# %%
def get_video_comment(youtube,video_id):
  request=youtube.commentThreads().list(
        part='snippet',
        videoId=video_id
    )
  data=[]
  res=request.execute()

  for i in range(len(res['items'])):
    data.append(res['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'])
    #print(data)
  return data

# %%
video_comment=[]

# %%
for i in range(len(list_id)):
  print(len(list_id))
  print(list_id[i])

  video_comment.append(get_video_comment(youtube,list_id[i]))
# Out:
# 42401
# y6E1L6KVwYw
# 42401
# jCbEI2-mFMQ
# 42401
# YEok4Ykw204
# 42401
# o0PT6bOwfFM
# 42401
# Wt4XODPm4hA
# 42401
# 0XoT1z-gAQw
# 42401
# T2B0WuJegfY
# 42401
# ycMPXockKn0
# 42401
# 3SsK-cxlj_w
# 42401
# bAEprBbAfZM
# 42401
# FyR05ZQdx6U
# 42401
# Jgegx5BH5xM
# 42401
# MQROYY0dY9A
# 42401
# fpVsrsvwe4M
# 42401
# dNU1lJiDaSY
# 42401
# MZO4B1RZU5g
# 42401
# stGfw_T821g
# 42401
# wSHXd-K-jIk
# 42401
# KmNNS-EsgT0
# 42401
# SwIB-QlxNCo
# 42401
# 6KjOfVTX10Q
# 42401
# wAppCTDtW3Y
# 42401
# _gWGwPp09CA
# 42401
# q7zdJ-nMrlE
# 42401
# Nye_O4PEh7k
# 42401
# CxuiFNYnEr4
# 42401
# sKDQFvw-wrM
# 42401
# NUDBwBJeKvY
# 42401
# 32AciEK2P5Y
# 42401
# 7lvXbfNBIQg
# 42401
# IwtNFzX0ni8
# 42401
# ZjFzkhrqIZs
# 42401
# u_f90pXw5sQ
# 42401
# DXXxANXLQyE
# 42401
# dKTDQa20IEQ
# 42401
# VtXuGg0Qkro
# 42401
# BHdIQy00_p4
# 42401
# L5JORXmV_A0
# 42401
# vNQR3ixE8AE
# 42401
# T60_zAvnAsU
# 42401
# vdIDF9mbiyM
# 42401
# Y65_Qs1Wq0w
# 42401
# VoBBHAw4EuU
# 42401
# RwPQQ6I7LE4
# 42401
# OpyxUpX1Pj8
# 42401
# ...

# %%
video_comment

# %%
len(video_comment)
# Out:
# 275

# %%
for i in range(len(video_comment)):
  print(video_comment[i])

# %%
list_comment=[]

# %%
for i in range(len(video_comment)):
  print(video_comment[i])
  #print(len(video_comment[i]))
  for j in range(len(video_comment[i])):
    print(video_comment[i][j])
    list_comment.append(video_comment[i][j])
  #comment.append(pd.DataFrame(video_comment[i]))
# Out:
# ['I promise one day touropia will use my songs on their video. I love this county😍😍', 'So good', '<a href="https://youtu.be/zY3Izzv0Wsg">https://youtu.be/zY3Izzv0Wsg</a><br>पहाड़ की लाईफ स्टाइल', 'Thanks you for updating I appreciate your efforts touropia', 'Thanks you for updating I appreciate your efforts thank you', 'Wonderful video! All of these countries really do have extraordinary and stunning places worth visiting. 😍✨', 'Super ! ❤☆', 'Can&#39;t live without hearing you...so attractive way of speaking period <br>Love ❤ from India 🇮🇳', 'Europe is beautiful ❤❤', 'I can’t believe Ireland wasn’t on the list 😮', 'Just turkey 🇹🇷 Greece 🇬🇷', 'Finland', 'italia molto bella paese nel mondo....where is turkey in this video ???', '# 1 Greece, but no mention of Turkey at all! Love all the countries though :)', 'Athens the ugliest city ever', 'and the other countries are very beautiful but Greece is in our hearts and they put Thessaloniki in the video double love. ❤ 🥰🇬🇷', 'Würzburg, German
# ...

# %%
list_comment

# %%
f=pd.DataFrame(list_comment)

# %%
f

# %% [markdown]
# extra

# %%
f.to_csv('train4_data.csv')
